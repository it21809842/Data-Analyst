# %% [markdown]
# <a href="https://colab.research.google.com/github/it21809842/Data-Analyst/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file_path = "/content/clean data set.xlsx"
df = pd.read_excel(file_path)

# %%
df.head()
df.shape
# Out:
# (8503, 37)

# %% [markdown]
# [lData Cleaning]

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

# %%
df.columns
# Out:
# Index(['date', 'country', 'keyword', 'yp', 'yp_visibility', 'yp_type',
#        'yp_landing', 'yp_difference', 'yp_visibility_difference', 'sc',
#        'sc_visibility', 'sc_type', 'sc_landing', 'sc_difference',
#        'sc_visibility_difference', 'syc', 'syc_visibility', 'syc_type',
#        'syc_landing', 'syc_difference', 'syc_visibility_difference', 'sysg',
#        'sysg_visibility', 'sysg_type', 'sysg_landing', 'sysg_difference',
#        'sysg_visibility_difference', 'bi', 'bi_visibility', 'bi_type',
#        'bi_landing', 'bi_difference', 'bi_visibility_difference', 'intents',
#        'cpc', 'search_volume', 'keyword_difficulty'],
#       dtype='object')

# %%
rank_cols = ["yp", "sc", "syc", "sysg", "bi"]

for col in rank_cols:
    df[col] = df[col].fillna(100)
    df[col] = df[col].replace(0, 100)

# %%
numeric_cols = [
    "yp_visibility", "sc_visibility", "syc_visibility",
    "sysg_visibility", "bi_visibility",
    "search_volume", "keyword_difficulty", "cpc"
]

df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")

# %%
competitor_summary = pd.DataFrame({
    "domain": ["Yachting Pages", "Superyacht Times", "Superyacht Content", "SY Services Guide", "Boat International"],
    "total_visibility": [
        df["yp_visibility"].sum(),
        df["sc_visibility"].sum(),
        df["syc_visibility"].sum(),
        df["sysg_visibility"].sum(),
        df["bi_visibility"].sum()
    ]
})

# %%
competitor_summary["top_10_keywords"] = [
    (df["yp"] <= 10).sum(),
    (df["sc"] <= 10).sum(),
    (df["syc"] <= 10).sum(),
    (df["sysg"] <= 10).sum(),
    (df["bi"] <= 10).sum()
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3464204495.py in <cell line: 0>()
#       1 competitor_summary["top_10_keywords"] = [
# ----> 2     (df["yp"] <= 10).sum(),
#       3     (df["sc"] <= 10).sum(),
#       4     (df["syc"] <= 10).sum(),
#       5     (df["sysg"] <= 10).sum(),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __le__(self, other)
#      50     @unpack_zerodim_and_defer("__le__")
#      51     def __le__(self, other):
# ---> 52         return self._cmp_method(other, operator.le)
#      53
#      54     @unpack_zerodim_and_defer("__gt__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6117         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6118
# -> 6119         res_values = ops.comparison_op(lvalues, rvalues, op)
#    6120
#    6121         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     342
#     343     elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     345
#     346     else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#     127         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128     else:
# --> 129         result = libops.scalar_compare(x.ravel(), y, op)
#     130     return result.reshape(x.shape)
#     131
#
# ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
df.dtypes
# Out:
# date                           object
# country                        object
# keyword                        object
# yp                             object
# yp_visibility                 float64
# yp_type                        object
# yp_landing                     object
# yp_difference                  object
# yp_visibility_difference      float64
# sc                            float64
# sc_visibility                 float64
# sc_type                        object
# sc_landing                     object
# sc_difference                  object
# sc_visibility_difference      float64
# syc                            object
# syc_visibility                float64
# syc_type                       object
# syc_landing                    object
# syc_difference                float64
# syc_visibility_difference     float64
# sysg                          float64
# sysg_visibility               float64
# sysg_type                      object
# sysg_landing                   object
# sysg_difference               float64
# sysg_visibility_difference    float64
# bi                            float64
# bi_visibility                 float64
# bi_type                        object
# bi_landing                     object
# bi_difference                 float64
# bi_visibility_difference      float64
# intents                        object
# cpc                           float64
# search_volume                 float64
# keyword_difficulty            float64
# dtype: object

# %%
rank_cols = ["yp", "sc", "syc", "sysg", "bi"]

for col in rank_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
df[rank_cols] = df[rank_cols].fillna(100)

# %%
competitor_summary["top_10_keywords"] = [
    (df["yp"] <= 10).sum(),
    (df["sc"] <= 10).sum(),
    (df["syc"] <= 10).sum(),
    (df["sysg"] <= 10).sum(),
    (df["bi"] <= 10).sum()
]

# %%
visibility_cols = [
    "yp_visibility", "sc_visibility",
    "syc_visibility", "sysg_visibility",
    "bi_visibility"
]

df[visibility_cols] = df[visibility_cols].apply(
    pd.to_numeric, errors="coerce"
)

# %%
df[rank_cols + visibility_cols].describe()
# Out:
#                 yp           sc          syc         sysg           bi  \
# count  8503.000000  8503.000000  8503.000000  8503.000000  8503.000000
# mean     43.216277    69.379043    87.800894    79.664824    65.068211
# std      38.520793    35.544515    25.750179    32.665338    37.992506
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      10.000000    33.000000   100.000000    59.000000    26.000000
# 50%      25.000000    95.000000   100.000000   100.000000    85.000000
# 75%     100.000000   100.000000   100.000000   100.000000   100.000000
# max     101.000000   107.000000   100.000000   102.000000   103.000000
#
#        yp_visibility  sc_visibility  syc_visibility  sysg_visibility  \
# count    7884.000000    7883.000000     7884.000000      7884.000000
# mean        0.038997       0.012239        0.003784         0.006892
# std         0.084100       0.045198        0.024255         0.025662
# min         0.000000       0.000000        0.000000         0.000000
# 25%         0.004237       0.000000        0.000000         0.000000
# 50%         0.012290       0.002130        0.000000         0.000000
# 75%         0.037630       0.010165        0.000000         0.006020
# max         0.456620       0.456620        0.456620         0.456620
#
#        bi_visibility
# count    7884.000000
# mean        0.020732
# std         0.066320
# min         0.000000
# 25%         0.000000
# 50%         0.003510
# 75%         0.011790
# max         0.456620

# %%
competitor_summary["avg_position"] = [
    df.loc[df["yp"] < 100, "yp"].mean(),
    df.loc[df["sc"] < 100, "sc"].mean(),
    df.loc[df["syc"] < 100, "syc"].mean(),
    df.loc[df["sysg"] < 100, "sysg"].mean(),
    df.loc[df["bi"] < 100, "bi"].mean()
]

# %%
competitor_summary.to_csv("competitor_summary.csv", index=False)
competitor_summary
# Out:
#                domain  total_visibility  top_10_keywords  avg_position
# 0      Yachting Pages         307.45552             2175     22.746560
# 1    Superyacht Times          96.48339              544     40.479771
# 2  Superyacht Content          29.83184              133     45.861691
# 3   SY Services Guide          54.33984              419     38.021864
# 4  Boat International         163.45017              959     34.916959

# %%
gap_df = df[
    (
        ((df["bi"] <= 10) | (df["sc"] <= 10)) &
        (df["yp"] > 20) &
        (df["search_volume"] > 100) &
        (df["keyword_difficulty"] < 40)
    )
].copy()

# %%
gap_df["priority_score"] = (
    gap_df["search_volume"] /
    gap_df["keyword_difficulty"]
)

# %%
top_seo_opportunities = gap_df[
    [
        "keyword", "country", "yp", "bi", "sc",
        "search_volume", "keyword_difficulty",
        "intents", "priority_score"
    ]
].sort_values("priority_score", ascending=False)

# %%
top_seo_opportunities.to_csv("top_seo_opportunities.csv", index=False)
top_seo_opportunities.head(10)
# Out:
#                     keyword country     yp    bi    sc  search_volume  \
# 4576             yacht fuel     USA  100.0   1.0  55.0          110.0
# 423   yacht interior design     USA  100.0   6.0  39.0          260.0
# 7109  yacht interior design     USA   82.0   6.0  23.0          260.0
# 2548  yacht interior design     USA   82.0   6.0  23.0          260.0
# 4522  yacht interior design     USA   83.0   9.0  39.0          260.0
# 2509  superyacht management     USA   32.0  36.0   8.0          140.0
# 7070  superyacht management     USA   32.0  36.0   8.0          140.0
# 4492   superyacht insurance     USA   38.0   7.0  12.0          140.0
#
#       keyword_difficulty intents  priority_score
# 4576                 3.0       i       36.666667
# 423                 15.0       i       17.333333
# 7109                17.0     i|c       15.294118
# 2548                17.0     i|c       15.294118
# 4522                23.0       i       11.304348
# 2509                25.0       c        5.600000
# 7070                25.0       c        5.600000
# 4492                32.0       i        4.375000

# %% [markdown]
# INTENT ANALYSIS

# %%
visibility_by_intent = df.groupby("intents")[[
    "yp_visibility", "sc_visibility",
    "syc_visibility", "sysg_visibility",
    "bi_visibility"
]].sum().reset_index()

# %%
visibility_by_intent.columns = [
    "intent", "yp", "sc", "syc", "sysg", "bi"
]

# %%
visibility_by_intent.to_csv("visibility_by_intent.csv", index=False)
visibility_by_intent
# Out:
#   intent         yp        sc       syc      sysg         bi
# 0      c   20.61614   5.03110   1.67673   6.21893    9.51243
# 1      i  160.41015  49.56224  12.73488  26.18635  100.37914
# 2    i|c   80.82820  33.25735  11.22477  16.04240   41.74224
# 3    i|t   24.08076   6.07143   3.48183   4.39418    8.60948
# 4      n   18.58308   2.12738   0.57000   1.31133    2.27396
# 5    n|c    0.02358   0.05870   0.01179   0.00728    0.07375
# 6    n|t    0.15141   0.02972   0.06523   0.01455    0.14050
# 7      t    0.23724   0.10536   0.00000   0.03762    0.16056

# %% [markdown]
# LOW-HANGING FRUIT

# %%
low_hanging = df[
    (df["yp"] >= 11) & (df["yp"] <= 15)
].sort_values("search_volume", ascending=False)

# %%
low_hanging[
    ["keyword", "country", "yp", "search_volume", "keyword_difficulty"]
].head(10)
# Out:
#                    keyword country    yp  search_volume  keyword_difficulty
# 6613           yacht sails     UK   15.0          170.0                29.0
# 2052           yacht sails      UK  15.0          170.0                29.0
# 7022  superyacht insurance     USA  12.0          140.0                23.0
# 7490         yacht rigging   Spain  14.0          140.0                31.0
# 2461  superyacht insurance     USA  12.0          140.0                23.0
# 2929         yacht rigging   Spain  14.0          140.0                31.0
# 5316           yacht glass  Turkey  11.0           90.0                 8.0
# 3353           yacht glass  Turkey  13.0           90.0                 6.0
# 3357        yacht surveyor  Turkey  14.0           90.0                 7.0
# 1173           yacht glass  Turkey  14.0           90.0                 8.0
